# %% [markdown]
# # Extension One Notebook:

# %% [markdown]
# The baseline assumes that the system has only one AV. Clearly, this is a limited case; in many cases we may be interested in mixed-autonomy settings which involve a number of AVs. Thus, the first extension investigates how the system behaves as the proportion of AVs in the system increases.
#
# Run the cells below to execute the experiments, illustrate the results, plot system metrics, and save the visualizations in the "outputs" folder.

# %%
# Automatically reload custom code modules when there are changes:
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Adjust relative path so that the notebook can find the code modules:
import sys
sys.path.append('../code/')

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('seaborn-darkgrid')

# %%
# Import code modules:
from structures import RingRoad
from extension_one import extension_one
from extension_three import extension_three

# %%
# Hide warnings about safe distance violation (still in development):
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# In the figures below, the green vehicles are AVs, the blue vehicles are human-driven cars, and the pink shaded area is the 'safety zone' behind each vehicle.

# %%
num_vehicles = 22

# Scale the proportion of AVs in the system (from 0% to 100%) and record the results for each
# Then, plot the results 
extension_one(num_vehicles, show_fig=True)

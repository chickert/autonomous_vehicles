# %%
# Automatically reload custom code modules when there are changes:
# %load_ext autoreload
# %autoreload 2

# %%
# Adjust relative path so that the notebook can find the code modules:
import sys
sys.path.append('code/')

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Import code modules:
from structures import *
from extensions import *

# %%
# Hide warnings about safe distance violation (still in development):
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# Note that we scaled down the "starting_noise" parameter since HV heterogeneity achieved the same effect and if we did not scale it down initially, the vehicles would wreck before we could conduct enough experiments to gather interesting data.

# %%
extension_two(a_sigma_start=0.,
              a_sigma_stop=2.0,
              a_sigma_granularity=0.1,
              b_sigma_start=0.,
              b_sigma_stop=60.0,
              b_sigma_granularity=3.0,
              )
# Out:
# Computing values for 400 combinations
# On combintion #10
# On combintion #20
# On combintion #30
# On combintion #40
# On combintion #50
# On combintion #60
# On combintion #70
# On combintion #80
# On combintion #90
# On combintion #100
# On combintion #110
# On combintion #120
# On combintion #130
# On combintion #140
# On combintion #150
# On combintion #160
# On combintion #170
# On combintion #180
# On combintion #190
# On combintion #200
# On combintion #210
# On combintion #220
# On combintion #230
# On combintion #240
# On combintion #250
# On combintion #260
# On combintion #270
# On combintion #280
# On combintion #290
# On combintion #300
# On combintion #310
# On combintion #320
# On combintion #330
# On combintion #340
# On combintion #350
# On combintion #360
# On combintion #370
# On combintion #380
# On combintion #390
# On combintion #400

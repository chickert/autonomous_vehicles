# %%
# Automatically reload custom code modules when there are changes:
# %load_ext autoreload
# %autoreload 2

# %%
# Adjust relative path so that the notebook can find the code modules:
import sys
sys.path.append('code/')

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Import code modules:
from structures import *
from extensions import *

# %%
# Hide warnings about safe distance violation (still in development):
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
extension_two(a_sigma_start=0.,
                  a_sigma_stop=0.08,
                  a_sigma_granularity=0.0025,
                  b_sigma_start=0.,
                  b_sigma_stop=1.0,
                  b_sigma_granularity=0.05,
                  )
# Out:
# Computing values for 640 combinations
# On combintion #25
# On combintion #50
# On combintion #75
# On combintion #100
# On combintion #125
# On combintion #150
# On combintion #175
# On combintion #200
# On combintion #225
# On combintion #250
# On combintion #275
# On combintion #300
# On combintion #325
# On combintion #350
# On combintion #375
# On combintion #400
# On combintion #425
# On combintion #450
# On combintion #475
# On combintion #500
# On combintion #525
# On combintion #550
# On combintion #575
# On combintion #600
# On combintion #625
